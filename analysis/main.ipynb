# %%
import pandas as pd

# %%
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)

# %%
df = pd.read_json('./data/flats_sell_21_01_2023.json', orient='records')

# %%
df
# Out:
#          id_ public_id                                               slug  \
# 0   63862596     4jXzS  dom-na-dzialce-lesno-budowlanej-nieopodal-zale...
# 1   63858154     4jVqe      dom-w-zabudowie-blizniaczej-z-garazem-ID4jVqe
# 2   63852365     4jUUR  sprzedam-3-pokojowe-mieszkanie-na-bielanach-ID...
# 3   63856692     4jV2E               metro-bemowo-36-5m2-2-pokoje-ID4jV2E
# 4   63851139     4jUB5  mieszkanie-skwer-kosciuszki-71-mkw-wyposazone-...
# 5   63865743     4jYoD  nowe-domy-premium-krap-otmet-odbior-maj-2023-I...
# 6   63861559     4jXj9        sprzedam-mieszkanie-kutno-ul-1-maja-ID4jXj9
# 7   63858990     4jVDI             srodmiescie-m3-rozkladowe-45m2-ID4jVDI
# 8   63863633     4jXQB        apartament-miedzywodzie-plaza-200-m-ID4jXQB
# 9   63851613     4jUIJ  mieszkanie-z-ogrodkiem-wys-stand-bialoleka-ID4...
# 10  63871729     4jZXb                   3-pokoje-na-ul-balladyny-ID4jZXb
# 11  63871740     4jZXm             dom-w-skowarczu-140-m2-6-pokoi-ID4jZXm
# ...

# %%
sorted(df.columns)
# Out:
# ['access_type',
#  'advert_type',
#  'advertiser_type',
#  'air_conditioning',
#  'alarm',
#  'all_features',
#  'all_medias',
#  'anti_burglary_door',
#  'area',
#  'attic',
#  'balcony',
#  'basement',
#  'build_year',
#  'building_floors_num',
#  'building_material',
#  'building_ownership',
#  'building_type',
#  'city',
#  'closed_area',
#  'construction_status',
#  'county',
#  'created_at',
#  'description',
#  'dishwasher',
#  'electricity',
#  'entryphone',
#  'equipment_types',
#  'estate_floors_num',
#  'extras_types',
#  'fence',
#  'floor_no',
#  'fridge',
#  'furniture',
#  'garage',
#  'garden',
#  'gas',
#  'heating',
#  'id_',
#  'internet',
#  'latitude',
#  'lift',
#  'location_type',
#  'longitude',
#  'market_type',
#  'modified_at',
#  'monitoring',
#  'offer_type',
#  'oven',
#  'owner_id',
#  'owner_name',
#  'owner_type',
#  'phone',
#  'phones',
#  'pool',
#  'price',
#  'price_per_m',
#  'price_range_max',
#  'price_range_min',
#  'proper_type',
# ...

# %%
df['url'][0]
# Out:
# 'https://www.otodom.pl/pl/oferta/dom-na-dzialce-lesno-budowlanej-nieopodal-zalewu-ID4jXzS'
